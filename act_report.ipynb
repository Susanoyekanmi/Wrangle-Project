# %% [markdown]
# ## Report: act_report
#
# GOAL: The goal of this act report is to communicate the analysis/insights done
#
# in the wrangle_act_ipynb section of this data wrangling project in which
#
# proper visualization was carried using  matplotlib.This analysis was however
#
# made/posed from the twitteraccount known as WeRatedogs consisting of three
#
# different dataset(twitter_archived_enhanced,image_predictions.tsv,tweet_json-
#
# txt) gathered differently

# %% [markdown]
# This insights are;

# %% [markdown]
# CORRELATION BETWEEN DOG NAMES AND DOG RATES
#
# There wasn_t any noticeable correlation between dog name and ratings

# %% [markdown]
# MOST COMMON DOG BREED
#
# The most common dog breed in terms of its type was that of pupper dog type

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# MOST COMMON DOG NAME
#
# The name which is most famous is charlie ,hence the most popular dog name is  charlie

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CONCLUSION
#
#
# THIS REPORT OFFERS A SUUMARY OF THE VISUALIZATION PART OF THE DATA  WRANGLING
#
#
# PROJECT.

# %%
from subprocess import call
call(['python','-m', 'nbconvert', 'act_report.ipynb'])
# Out:
# 0
